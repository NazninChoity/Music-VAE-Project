# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from src.dataset import AudioFeatureDataset
from src.clustering import get_latents, kmeans_and_metrics, visualize_umap
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 from src.dataset import AudioFeatureDataset
# ----> 2 from src.clustering import get_latents, kmeans_and_metrics, visualize_umap
#
# ImportError: cannot import name 'get_latents' from 'src.clustering' (c:\Users\rakib\Music-VAE-Project\src\clustering.py)
